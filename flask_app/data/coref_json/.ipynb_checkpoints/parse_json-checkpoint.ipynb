# %%
import json

from pprint import pprint

with open("Werther_IH.json") as f:
    data = json.load(f)

# %%
data
# Out:
# [{'surface': '\ufeffDie'},
#  {'surface': 'Leiden'},
#  {'entities': [0], 'surface': 'des'},
#  {'entities': [0], 'surface': 'jungen'},
#  {'entities': [0], 'surface': 'Werther'},
#  {'surface': '.'},
#  {'surface': 'Erstes'},
#  {'surface': 'Buch'},
#  {'surface': '.'},
#  {'entities': [1], 'surface': 'Was'},
#  {'entities': [1, 2], 'surface': 'ich'},
#  {'entities': [1], 'surface': 'von'},
#  {'entities': [1], 'surface': 'der'},
#  {'entities': [1], 'surface': 'Geschichte'},
#  {'entities': [1, 0], 'surface': 'des'},
#  {'entities': [1, 0], 'surface': 'armen'},
#  {'entities': [1, 0], 'surface': 'Werther'},
#  {'entities': [1], 'surface': 'nur'},
#  {'entities': [1], 'surface': 'habe'},
#  {'entities': [1], 'surface': 'auffinden'},
#  {'entities': [1], 'surface': 'können'},
#  {'surface': ','},
#  {'surface': 'habe'},
#  {'entities': [2], 'surface': 'ich'},
#  {'surface': 'mit'},
#  {'surface': 'Fleiß'},
#  {'surface': 'gesammelt'},
#  {'surface': 'und'},
#  {'surface': 'lege'},
# ...
