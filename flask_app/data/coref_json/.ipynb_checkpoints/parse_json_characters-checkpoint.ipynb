# %%
import json
from pprint import pprint
from collections import defaultdict
from operator import itemgetter
from itertools import *
import spacy
import numpy as np

nlp = spacy.load('de_core_news_sm')

# %%
with open('Werther_IH.json') as f:
    data = json.load(f)

text = {} # CREATE a dictionary that holds the text, key is position, value is token
for n,each in enumerate(data):
    text[n]=each['surface']

text_str = str()

for k,v in text.items():
    text_str+=v+" "

doc = nlp(text_str)

pos = []
for token in doc:
    pos.append(token.pos_)

for i,b in zip(pos,data):
    b['pos']=i

# %%
names = open("1_Goethe_Werther_74_characters.txt")
allowed_names = []
for line in names:
    line = line.strip().split('\t')
    for item in line:
        if not item == "." and not item == "Der" and not item == "der":
            allowed_names.append(item)

positions = defaultdict(list)

for n,each in enumerate(data):
    if each['surface'] in allowed_names:
        try:
            for i in each['entities']:
                positions[i].append((n,each['pos'],each['surface']))            
        except KeyError:
            pass
        continue
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-0ad4f4604ab3> in <module>()
# ----> 1 names = open("1_Goethe_Werther_74_characters.txt")
#       2 allowed_names = []
#       3 for line in names:
#       4     line = line.strip().split('\t')
#       5     for item in line:
#
# FileNotFoundError: [Errno 2] No such file or directory: '1_Goethe_Werther_74_characters.txt'

# %%
name_clean = []

for k,v in positions.items():
    temp_names = str()
    for each in v:
        if each[2]!="Ich" and each[2]!="ich":
            if each[2] in allowed_names:
                temp_names = each[2]
    name_clean.append([temp_names, v])

# %%
name_clean
# Out:
# [['Werther',
#   [(4, 'NOUN', 'Werther'),
#    (16, 'NOUN', 'Werther'),
#    (111, 'AUX', 'ich'),
#    (114, 'SCONJ', 'ich'),
#    (133, 'PRON', 'ich'),
#    (139, 'PRON', 'ich'),
#    (148, 'PUNCT', 'Ich'),
#    (181, 'ADV', 'ich'),
#    (186, 'ADJ', 'ich'),
#    (217, 'PUNCT', 'ich'),
#    (223, 'NOUN', 'ich'),
#    (231, 'X', 'ich'),
#    (261, 'X', 'ich'),
#    (277, 'VERB', 'Ich'),
#    (283, 'NOUN', 'ich'),
#    (287, 'PRON', 'ich'),
#    (313, 'ADV', 'ich'),
#    (391, 'PART', 'ich'),
#    (404, 'ADV', 'Ich'),
#    (438, 'DET', 'Ich'),
#    (477, 'PUNCT', 'ich'),
#    (495, 'ADJ', 'ich'),
#    (535, 'ADJ', 'ich'),
#    (686, 'DET', 'ich'),
#    (706, 'AUX', 'ich'),
#    (753, 'ADJ', 'ich'),
#    (759, 'ADJ', 'Ich'),
#    (782, 'CONJ', 'Ich'),
#    (806, 'NOUN', 'Ich'),
#    (861, 'ADJ', 'ich'),
#    (884, 'ADJ', 'ich'),
#    (969, 'DET', 'ich'),
#    (1022, 'PUNCT', 'ich'),
#    (1028, 'VERB', 'ich'),
#    (1043, 'ADP', 'Ich'),
#    (1089, 'DET', 'ich'),
#    (1170, 'VERB', 'ich'),
#    (1207, 'NOUN', 'ich'),
#    (1287, 'VERB', 'ich'),
#    (1300, 'PRON', 'Ich'),
#    (1320, 'ADV', 'ich'),
#    (1326, 'VERB', 'ich'),
#    (1339, 'PUNCT', 'ich'),
#    (1364, 'PUNCT', 'ich'),
#    (1397, 'ADP', 'ich'),
#    (1448, 'ADV', 'ich'),
#    (1467, 'PRON', 'ich'),
#    (1480, 'ADV', 'Ich'),
#    (1489, 'PART', 'ich'),
#    (1492, 'ADV', 'ich'),
#    (1549, 'NOUN', 'Ich'),
#    (1564, 'PUNCT', 'ich'),
#    (1614, 'PART', 'ich'),
#    (1652, 'ADP', 'Ich'),
#    (1662, 'VERB', 'ich'),
#    (1669, 'PRON', 'ich'),
#    (1699, 'PRON', 'ich'),
#    (1714, 'PUNCT', 'Ich'),
#    (1722, 'DET', 'ich'),
#    (1727, 'AUX', 'Ich'),
#    (1732, 'PUNCT', 'ich'),
#    (1780, 'ADV', 'ich'),
#    (1849, 'DET', 'ich'),
#    (1926, 'PUNCT', 'ich'),
#    (1969, 'NOUN', 'ich'),
#    (1976, 'PRON', 'Ich'),
#    (1996, 'ADV', 'ich'),
#    (2001, 'PUNCT', 'ich'),
#    (2014, 'DET', 'ich'),
#    (2021, 'PRON', 'ich'),
#    (2025, 'PART', 'ich'),
#    (2029, 'AUX', 'ich'),
#    (2047, 'NOUN', 'ich'),
#    (2120, 'ADP', 'ich'),
#    (2137, 'DET', 'ich'),
#    (2183, 'PRON', 'ich'),
#    (2200, 'ADJ', 'ich'),
#    (2264, 'ADP', 'Ich'),
#    (2276, 'AUX', 'ich'),
#    (2328, 'PRON', 'ich'),
#    (2446, 'PRON', 'ich'),
#    (2464, 'ADJ', 'ich'),
#    (2540, 'PRON', 'Ich'),
#    (2575, 'CONJ', 'ich'),
#    (2666, 'PUNCT', 'Ich'),
#    (2672, 'VERB', 'ich'),
#    (2948, 'DET', 'ich'),
#    (3065, 'AUX', 'ich'),
#    (3076, 'ADJ', 'ich'),
#    (3133, 'CONJ', 'ich'),
#    (3147, 'DET', 'ich'),
#    (3225, 'ADV', 'ich'),
#    (3245, 'CONJ', 'Ich'),
#    (3274, 'PUNCT', 'ich'),
#    (3432, 'ADJ', 'ich'),
#    (3592, 'PUNCT', 'ich'),
#    (3699, 'ADJ', 'Ich'),
#    (3703, 'VERB', 'ich'),
#    (3730, 'PRON', 'Ich'),
#    (3796, 'PUNCT', 'ich'),
#    (3945, 'PRON', 'Ich'),
#    (3981, 'PUNCT', 'Ich'),
#    (4083, 'VERB', 'ich'),
#    (4108, 'PRON', 'Ich'),
#    (4174, 'ADV', 'ich'),
#    (4191, 'DET', 'ich'),
#    (4217, 'PRON', 'ich'),
#    (4245, 'VERB', 'ich'),
#    (4290, 'VERB', 'ich'),
#    (4328, 'CONJ', 'Ich'),
#    (4426, 'PUNCT', 'ich'),
#    (4467, 'PUNCT', 'ich'),
#    (4505, 'VERB', 'ich'),
#    (4564, 'VERB', 'ich'),
#    (4643, 'PRON', 'ich'),
#    (4668, 'ADJ', 'ich'),
#    (4739, 'PUNCT', 'ich'),
#    (4784, 'VERB', 'ich'),
#    (4793, 'PRON', 'Ich'),
#    (4816, 'NOUN', 'ich'),
#    (4832, 'VERB', 'ich'),
#    (4864, 'PUNCT', 'ich'),
#    (4875, 'VERB', 'Ich'),
#    (4894, 'PUNCT', 'ich'),
#    (4902, 'ADV', 'ich'),
#    (4932, 'ADP', 'ich'),
#    (4945, 'PUNCT', 'ich'),
#    (4967, 'PUNCT', 'ich'),
#    (4979, 'PRON', 'ich'),
#    (4991, 'PUNCT', 'Ich'),
#    (4994, 'ADJ', 'ich'),
#    (5010, 'PUNCT', 'ich'),
#    (5023, 'PRON', 'Ich'),
#    (5054, 'NOUN', 'ich'),
#    (5149, 'DET', 'ich'),
#    (5171, 'PUNCT', 'ich'),
#    (5178, 'PUNCT', 'ich'),
#    (5198, 'PRON', 'ich'),
#    (5228, 'ADV', 'Ich'),
#    (5234, 'NOUN', 'ich'),
#    (5242, 'NOUN', 'ich'),
#    (5283, 'ADP', 'ich'),
#    (5301, 'VERB', 'ich'),
#    (5310, 'PRON', 'Ich'),
#    (5316, 'CONJ', 'ich'),
#    (5347, 'VERB', 'Ich'),
#    (5387, 'VERB', 'ich'),
#    (5395, 'VERB', 'Ich'),
#    (5415, 'VERB', 'ich'),
#    (5491, 'PUNCT', 'ich'),
#    (5585, 'PUNCT', 'Ich'),
#    (5608, 'PRON', 'Ich'),
#    (5634, 'PUNCT', 'Ich'),
#    (5646, 'PRON', 'ich'),
#    (5858, 'ADP', 'Ich'),
#    (5880, 'ADP', 'ich'),
#    (5921, 'DET', 'ich'),
#    (5956, 'NOUN', 'Vetter'),
#    (5969, 'ADV', 'ich'),
#    (5990, 'NOUN', 'ich'),
#    (5993, 'PUNCT', 'ich'),
#    (6003, 'ADP', 'ich'),
#    (6320, 'ADV', 'Ich'),
#    (6324, 'PUNCT', 'ich'),
#    (6341, 'DET', 'Ich'),
#    (6352, 'SCONJ', 'ich'),
#    (6386, 'ADJ', 'ich'),
#    (6530, 'NOUN', 'Ich'),
#    (6595, 'NOUN', 'ich'),
#    (6615, 'VERB', 'ich'),
#    (6624, 'SCONJ', 'ich'),
#    (6738, 'VERB', 'ich'),
#    (6764, 'AUX', 'ich'),
#    (6802, 'DET', 'ich'),
#    (6876, 'PUNCT', 'ich'),
#    (6931, 'ADJ', 'ich'),
#    (6946, 'NOUN', 'ich'),
#    (7067, 'ADJ', 'Ich'),
#    (7191, 'PUNCT', 'Ich'),
#    (7315, 'PRON', 'Ich'),
#    (7352, 'ADJ', 'ich'),
#    (7363, 'DET', 'ich'),
#    (7368, 'NOUN', 'ich'),
#    (7385, 'PUNCT', 'ich'),
#    (7472, 'VERB', 'ich'),
#    (7551, 'DET', 'ich'),
#    (7661, 'ADP', 'ich'),
#    (7686, 'PUNCT', 'ich'),
#    (7751, 'ADV', 'ich'),
#    (7855, 'SCONJ', 'ich'),
#    (8058, 'DET', 'Ich'),
#    (8212, 'PUNCT', 'Ich'),
#    (8267, 'ADP', 'ich'),
#    (8289, 'CONJ', 'Ich'),
#    (8382, 'ADV', 'ich'),
#    (8402, 'ADJ', 'Ich'),
#    (8433, 'NOUN', 'Ich'),
#    (8471, 'PUNCT', 'ich'),
#    (8489, 'DET', 'ich'),
#    (8498, 'PUNCT', 'ich'),
#    (8504, 'ADV', 'ich'),
#    (8515, 'NUM', 'ich'),
#    (8524, 'ADV', 'ich'),
#    (8534, 'PUNCT', 'ich'),
#    (8554, 'PUNCT', 'ich'),
#    (8591, 'AUX', 'ich'),
#    (8603, 'PRON', 'ich'),
#    (8610, 'ADV', 'ich'),
#    (8617, 'DET', 'ich'),
#    (8667, 'CONJ', 'ich'),
#    (8686, 'ADP', 'ich'),
#    (8705, 'NOUN', 'ich'),
#    (8730, 'PUNCT', 'Ich'),
#    (8753, 'NOUN', 'ich'),
#    (8758, 'CONJ', 'ich'),
#    (8779, 'NOUN', 'ich'),
#    (8786, 'PUNCT', 'ich'),
#    (8797, 'VERB', 'ich'),
#    (8812, 'PUNCT', 'ich'),
#    (8816, 'DET', 'ich'),
#    (8836, 'AUX', 'ich'),
#    (8868, 'PRON', 'ich'),
#    (8927, 'ADP', 'ich'),
#    (8992, 'PRON', 'ich'),
#    (9000, 'NOUN', 'Ich'),
#    (9013, 'ADV', 'ich'),
#    (9160, 'NOUN', 'ich'),
#    (9193, 'DET', 'ich'),
#    (9227, 'NOUN', 'ich'),
#    (9267, 'CONJ', 'ich'),
#    (9399, 'DET', 'ich'),
#    (9445, 'PUNCT', 'ich'),
#    (9450, 'CONJ', 'Ich'),
#    (9499, 'PRON', 'Werther'),
#    (9522, 'NOUN', 'ich'),
#    (9549, 'ADJ', 'ich'),
#    (9590, 'DET', 'ich'),
#    (9725, 'CONJ', 'Ich'),
#    (9746, 'ADV', 'ich'),
#    (9801, 'ADP', 'Ich'),
#    (10007, 'PUNCT', 'Ich'),
#    (10025, 'DET', 'ich'),
#    (10256, 'PUNCT', 'ich'),
#    (10331, 'ADP', 'ich'),
#    (10415, 'AUX', 'ich'),
#    (10481, 'ADV', 'ich'),
#    (10535, 'CONJ', 'ich'),
#    (10632, 'NOUN', 'Ich'),
#    (10645, 'PART', 'ich'),
#    (10722, 'PUNCT', 'ich'),
#    (10727, 'VERB', 'ich'),
#    (10832, 'ADP', 'ich'),
#    (10890, 'PRON', 'Ich'),
#    (10909, 'SCONJ', 'ich'),
#    (10915, 'ADV', 'ich'),
#    (10930, 'NOUN', 'ich'),
#    (10932, 'DET', 'ich'),
#    (11045, 'NOUN', 'ich'),
#    (11231, 'AUX', 'ich'),
#    (11323, 'DET', 'ich'),
#    (11480, 'CONJ', 'ich'),
#    (11494, 'PUNCT', 'Ich'),
#    (11544, 'ADJ', 'ich'),
#    (11552, 'PRON', 'ich'),
#    (11565, 'ADV', 'ich'),
#    (11616, 'PROPN', 'ich'),
#    (11667, 'NOUN', 'Ich'),
#    (11695, 'ADP', 'ich'),
#    (11700, 'ADP', 'ich'),
#    (11719, 'NOUN', 'Ich'),
#    (11737, 'DET', 'Ich'),
#    (11746, 'PRON', 'ich'),
#    (11785, 'NOUN', 'Ich'),
#    (11804, 'PRON', 'ich'),
#    (11813, 'ADP', 'ich'),
#    (11845, 'VERB', 'Ich'),
#    (11889, 'CONJ', 'ich'),
#    (11956, 'DET', 'Ich'),
#    (11962, 'ADJ', 'ich'),
#    (11979, 'PUNCT', 'ich'),
#    (12001, 'DET', 'ich'),
#    (12030, 'VERB', 'ich'),
#    (12170, 'ADP', 'ich'),
#    (12176, 'ADJ', 'ich'),
#    (12194, 'PRON', 'ich'),
#    (12230, 'VERB', 'ich'),
#    (12251, 'DET', 'Ich'),
#    (12310, 'AUX', 'Ich'),
#    (12344, 'PART', 'ich'),
#    (12367, 'VERB', 'ich'),
#    (12382, 'ADP', 'ich'),
#    (12415, 'PRON', 'ich'),
#    (12467, 'PRON', 'ich'),
#    (12474, 'DET', 'ich'),
#    (12479, 'DET', 'Ich'),
#    (12761, 'DET', 'Ich'),
#    (12803, 'PART', 'ich'),
#    (12829, 'ADJ', 'ich'),
#    (12834, 'SCONJ', 'Ich'),
#    (12849, 'NUM', 'ich'),
#    (12855, 'DET', 'ich'),
#    (12865, 'PRON', 'ich'),
#    (12868, 'NOUN', 'ich'),
#    (12889, 'PART', 'ich'),
#    (12895, 'PUNCT', 'ich'),
#    (12932, 'NOUN', 'Ich'),
#    (13018, 'VERB', 'Ich'),
#    (13097, 'PUNCT', 'ich'),
#    (13113, 'PUNCT', 'ich'),
#    (13163, 'VERB', 'Ich'),
#    (13172, 'PUNCT', 'ich'),
#    (13272, 'NOUN', 'ich'),
#    (13292, 'NOUN', 'ich'),
#    (13373, 'DET', 'ich'),
#    (13390, 'PART', 'Ich'),
#    (13415, 'ADV', 'ich'),
#    (13422, 'PUNCT', 'ich'),
#    (13427, 'NOUN', 'Ich'),
#    (13438, 'ADV', 'ich'),
#    (13513, 'ADP', 'Ich'),
#    (13562, 'PUNCT', 'Ich'),
#    (13569, 'AUX', 'ich'),
#    (13574, 'PRON', 'ich'),
#    (13588, 'PART', 'ich'),
#    (13596, 'PRON', 'ich'),
#    (13629, 'PUNCT', 'ich'),
#    (13640, 'PUNCT', 'Ich'),
#    (13682, 'DET', 'ich'),
#    (13696, 'SCONJ', 'ich'),
#    (13763, 'PUNCT', 'ich'),
#    (13770, 'PUNCT', 'ich'),
#    (13790, 'PUNCT', 'ich'),
#    (13817, 'PUNCT', 'Ich'),
#    (13822, 'PUNCT', 'ich'),
#    (13844, 'VERB', 'ich'),
#    (13851, 'ADV', 'ich'),
#    (13857, 'ADV', 'ich'),
#    (13869, 'NOUN', 'Ich'),
#    (13890, 'PART', 'ich'),
#    (13908, 'VERB', 'ich'),
#    (13920, 'PUNCT', 'ich'),
#    (13941, 'PRON', 'ich'),
#    (13962, 'NOUN', 'ich'),
#    (13979, 'VERB', 'ich'),
#    (13996, 'DET', 'Ich'),
#    (14021, 'PUNCT', 'ich'),
#    (14043, 'DET', 'ich'),
#    (14052, 'VERB', 'ich'),
#    (14057, 'DET', 'ich'),
#    (14086, 'PRON', 'ich'),
#    (14105, 'VERB', 'ich'),
#    (14112, 'DET', 'ich'),
#    (14127, 'PRON', 'Ich'),
#    (14139, 'DET', 'ich'),
#    (14193, 'PRON', 'ich'),
#    (14210, 'PUNCT', 'ich'),
#    (14263, 'PROPN', 'ich'),
#    (14312, 'PUNCT', 'ich'),
#    (14322, 'PROPN', 'ich'),
#    (14372, 'PUNCT', 'ich'),
#    (14429, 'NOUN', 'ich'),
#    (14458, 'NOUN', 'ich'),
#    (14489, 'VERB', 'ich'),
#    (14497, 'PRON', 'ich'),
#    (14528, 'NOUN', 'ich'),
#    (14547, 'PRON', 'Ich'),
#    (14551, 'ADV', 'ich'),
#    (14559, 'ADP', 'ich'),
#    (14563, 'PUNCT', 'ich'),
#    (14614, 'VERB', 'Ich'),
#    (14637, 'PRON', 'ich'),
#    (14660, 'PRON', 'Ich'),
#    (14669, 'PART', 'ich'),
#    (14684, 'ADJ', 'ich'),
#    (14691, 'PUNCT', 'ich'),
#    (14741, 'DET', 'ich'),
#    (14756, 'ADP', 'ich'),
#    (14767, 'ADV', 'ich'),
#    (14777, 'PUNCT', 'Ich'),
#    (14793, 'PRON', 'ich'),
#    (14808, 'PUNCT', 'Ich'),
#    (14876, 'VERB', 'ich'),
#    (15052, 'NOUN', 'Ich'),
#    (15072, 'DET', 'ich'),
#    (15087, 'PRON', 'ich'),
#    (15092, 'NOUN', 'ich'),
#    (15102, 'ADP', 'ich'),
#    (15117, 'CONJ', 'ich'),
#    (15122, 'CONJ', 'ich'),
#    (15136, 'PUNCT', 'ich'),
#    (15172, 'PRON', 'Ich'),
#    (15181, 'PRON', 'ich'),
#    (15422, 'NOUN', 'Ich'),
#    (15462, 'DET', 'Ich'),
#    (15467, 'DET', 'ich'),
#    (15502, 'PUNCT', 'ich'),
#    (15523, 'PUNCT', 'Ich'),
#    (15533, 'PRON', 'Ich'),
#    (15559, 'DET', 'ich'),
#    (15567, 'VERB', 'ich'),
#    (15591, 'NOUN', 'ich'),
#    (15623, 'PART', 'Ich'),
#    (15656, 'VERB', 'Ich'),
#    (15798, 'PUNCT', 'ich'),
#    (15816, 'PUNCT', 'ich'),
#    (15925, 'NOUN', 'ich'),
#    (15944, 'ADJ', 'ich'),
#    (15982, 'PART', 'ich'),
#    (16026, 'VERB', 'ich'),
#    (16129, 'PRON', 'Ich'),
#    (16145, 'PRON', 'ich'),
#    (16289, 'ADP', 'ich'),
#    (16344, 'PUNCT', 'Ich'),
#    (16367, 'AUX', 'ich')]],
#  ['Werther', [(10, 'PRON', 'ich'), (16, 'NOUN', 'Werther')]],
#  ['', [(10, 'PRON', 'ich'), (23, 'PRON', 'ich')]],
#  ['', [(133, 'PRON', 'ich')]],
#  ['', [(139, 'PRON', 'ich')]],
#  ['Leonore', [(176, 'DET', 'Leonore')]],
#  ['', [(287, 'PRON', 'ich'), (313, 'ADV', 'ich')]],
#  ['', [(1089, 'DET', 'ich')]],
#  ['', [(1089, 'DET', 'ich')]],
#  ['', [(1926, 'PUNCT', 'ich')]],
#  ['', [(2014, 'DET', 'ich'), (2021, 'PRON', 'ich')]],
#  ['Amtmann',
#   [(2282, 'NOUN', 'Amtmann'),
#    (5318, 'NOUN', 'Amtmann'),
#    (9375, 'NOUN', 'Amtmann'),
#    (10988, 'PRON', 'Amtmann')]],
#  ['Frau', [(2354, 'PUNCT', 'Frau')]],
#  ['Wilhelm',
#   [(2534, 'CONJ', 'Wilhelm'),
#    (4407, 'PRON', 'ich'),
#    (5245, 'PUNCT', 'Wilhelm'),
#    (7344, 'ADJ', 'Wilhelm'),
#    (8866, 'SCONJ', 'Wilhelm'),
#    (9508, 'ADP', 'Wilhelm'),
#    (9723, 'VERB', 'Wilhelm'),
#    (11960, 'ADP', 'Wilhelm'),
#    (13110, 'CONJ', 'Wilhelm'),
#    (13302, 'NOUN', 'Wilhelm'),
#    (13545, 'NOUN', 'Wilhelm'),
#    (14242, 'NOUN', 'Wilhelm'),
#    (14782, 'PUNCT', 'Wilhelm'),
#    (15070, 'ADP', 'Wilhelm'),
#    (15289, 'ADV', 'Wilhelm')]],
#  ['', [(3554, 'ADP', 'ich')]],
#  ['Frau',
#   [(3761, 'NOUN', 'Frau'),
#    (3847, 'ADJ', 'Ich'),
#    (3900, 'PRON', 'Ich'),
#    (4053, 'ADV', 'ich')]],
#  ['Hans', [(3903, 'NOUN', 'Hans')]],
#  ['', [(4489, 'VERB', 'ich')]],
#  ['', [(4945, 'PUNCT', 'ich')]],
#  ['', [(5149, 'DET', 'ich')]],
#  ['Charlotten',
#   [(5415, 'VERB', 'ich'),
#    (5425, 'PUNCT', 'Base'),
#    (5437, 'SCONJ', 'Charlotten')]],
#  ['Base',
#   [(5425, 'PUNCT', 'Base'),
#    (5478, 'NOUN', 'Base'),
#    (6278, 'NUM', 'Base'),
#    (6662, 'NOUN', 'Base'),
#    (6914, 'PUNCT', 'Base')]],
#  ['Charlotten', [(5437, 'SCONJ', 'Charlotten')]],
#  ['Gesellschafterin', [(5455, 'PUNCT', 'Gesellschafterin')]],
#  ['Magd', [(5614, 'NOUN', 'Magd'), (8644, 'DET', 'Magd')]],
#  ['Lotten',
#   [(5629, 'VERB', 'Lottchen'),
#    (5800, 'ADJ', 'Lotte'),
#    (5805, 'ADJ', 'Ich'),
#    (5814, 'SCONJ', 'ich'),
#    (5836, 'PRON', 'ich'),
#    (5944, 'PART', 'Lotte'),
#    (6133, 'AUX', 'Lottchen'),
#    (6219, 'PRON', 'Lotte'),
#    (6300, 'CONJ', 'Lotte'),
#    (6391, 'DET', 'ich'),
#    (6399, 'PRON', 'ich'),
#    (6414, 'SCONJ', 'ich'),
#    (6439, 'PRON', 'Ich'),
#    (6456, 'NOUN', 'ich'),
#    (6635, 'NOUN', 'Lotte'),
#    (6698, 'ADP', 'Lotte'),
#    (6702, 'PART', 'ich'),
#    (6706, 'ADV', 'ich'),
#    (6715, 'PRON', 'ich'),
#    (6833, 'PUNCT', 'Lottens'),
#    (6916, 'PRON', 'Lottens'),
#    (6975, 'PRON', 'Lotte'),
#    (7151, 'PUNCT', 'ich'),
#    (7183, 'PART', 'ich'),
#    (7524, 'ADP', 'Lotten'),
#    (7553, 'NOUN', 'Lotten'),
#    (7627, 'CONJ', 'ich'),
#    (7709, 'ADV', 'Lottens'),
#    (8029, 'VERB', 'Lotte'),
#    (8090, 'ADP', 'Ich'),
#    (8269, 'NOUN', 'Lotten'),
#    (8296, 'ADV', 'Ich'),
#    (8309, 'NOUN', 'ich'),
#    (8322, 'VERB', 'ich'),
#    (8792, 'VERB', 'Lotten'),
#    (9384, 'VERB', 'Lottens'),
#    (9738, 'NOUN', 'Lotte'),
#    (9795, 'AUX', 'Lotten'),
#    (9833, 'PRON', 'Lotte'),
#    (9867, 'PART', 'Lotten'),
#    (10171, 'NOUN', 'Lotte'),
#    (10250, 'NOUN', 'Lotten'),
#    (10317, 'PRON', 'Lotte'),
#    (10373, 'ADV', 'Lotten'),
#    (10403, 'DET', 'Lotte'),
#    (10668, 'PRON', 'Lotte'),
#    (10670, 'ADP', 'ich'),
#    (10680, 'AUX', 'Ich'),
#    (10698, 'ADV', 'ich'),
#    (11200, 'DET', 'Lotte'),
#    (11508, 'ADJ', 'Lottens'),
#    (11656, 'NOUN', 'Lotte'),
#    (11739, 'ADV', 'Lotten'),
#    (11777, 'PUNCT', 'Lottchen'),
#    (11842, 'PUNCT', 'Lotte'),
#    (11933, 'ADP', 'Lotte'),
#    (11974, 'DET', 'Lotte'),
#    (12041, 'ADV', 'Lotten'),
#    (12172, 'PUNCT', 'Lottens'),
#    (12253, 'PUNCT', 'Lottens'),
#    (12317, 'PUNCT', 'Lottens'),
#    (12476, 'VERB', 'Lotten'),
#    (12549, 'CONJ', 'Lotte'),
#    (12764, 'NOUN', 'Lotten'),
#    (12943, 'PUNCT', 'Lottens'),
#    (13376, 'NOUN', 'Lotten'),
#    (13887, 'PUNCT', 'Lottens'),
#    (13939, 'VERB', 'Lotte'),
#    (14283, 'PUNCT', 'Lotten'),
#    (14327, 'ADJ', 'Lottens'),
#    (14408, 'CONJ', 'Lotten'),
#    (14451, 'DET', 'Lotten'),
#    (14520, 'NOUN', 'Lotten'),
#    (14671, 'PUNCT', 'Lotten'),
#    (14712, 'VERB', 'Lotte'),
#    (14715, 'PRON', 'ich'),
#    (14902, 'ADP', 'Lotten'),
#    (15253, 'VERB', 'Lotten'),
#    (15307, 'DET', 'Lotten'),
#    (15349, 'VERB', 'Lotten'),
#    (15358, 'PRON', 'Lotten'),
#    (15370, 'PROPN', 'Lotten')]],
#  ['Louis', [(5951, 'ADJ', 'Louis')]],
#  ['Sophie', [(6099, 'PART', 'Sophie')]],
#  ['',
#   [(6391, 'DET', 'ich'),
#    (6399, 'PRON', 'ich'),
#    (6414, 'SCONJ', 'ich'),
#    (6439, 'PRON', 'Ich'),
#    (6456, 'NOUN', 'ich'),
#    (6484, 'CONJ', 'ich')]],
#  ['', [(6484, 'CONJ', 'ich')]],
#  ['', [(6530, 'NOUN', 'Ich')]],
#  ['', [(6530, 'NOUN', 'Ich')]],
#  ['Lotte',
#   [(6698, 'ADP', 'Lotte'),
#    (6702, 'PART', 'ich'),
#    (6706, 'ADV', 'ich'),
#    (6715, 'PRON', 'ich')]],
#  ['Audran', [(6896, 'AUX', 'Audran')]],
#  ['N', [(6900, 'ADV', 'N'), (6902, 'DET', 'N')]],
#  ['Lottens', [(6916, 'PRON', 'Lottens')]],
#  ['', [(7135, 'AUX', 'ich')]],
#  ['Dame', [(7187, 'AUX', 'Dame')]],
#  ['Audran', [(7298, 'SCONJ', 'Audran')]],
#  ['Audran', [(7298, 'SCONJ', 'Audran'), (12228, 'DET', 'Audran')]],
#  ['', [(7363, 'DET', 'ich')]],
#  ['', [(7417, 'DET', 'ich')]],
#  ['Frau', [(7503, 'PRON', 'Frau')]],
#  ['Albert', [(7538, 'ADJ', 'Albert')]],
#  ['Albert',
#   [(7548, 'PRON', 'Albert'),
#    (7620, 'SCONJ', 'Albert'),
#    (14189, 'ADV', 'Albert'),
#    (14556, 'PRON', 'Albert'),
#    (14674, 'VERB', 'Albert'),
#    (15259, 'PUNCT', 'Albert'),
#    (15278, 'PART', 'ich'),
#    (15280, 'PUNCT', 'Lotten'),
#    (15473, 'AUX', 'Albert'),
#    (15514, 'PUNCT', 'Albert'),
#    (15645, 'VERB', 'ich'),
#    (15666, 'PUNCT', 'Ich'),
#    (15700, 'ADV', 'ich'),
#    (15705, 'PRON', 'ich'),
#    (15735, 'AUX', 'Ich'),
#    (15841, 'CONJ', 'ich'),
#    (15962, 'PUNCT', 'Albert'),
#    (15996, 'PUNCT', 'Ich'),
#    (16111, 'PRON', 'Albert'),
#    (16257, 'SCONJ', 'Albert')]],
#  ['Albert', [(7620, 'SCONJ', 'Albert'), (7627, 'CONJ', 'ich')]],
#  ['', [(8090, 'ADP', 'Ich')]],
#  ['', [(8402, 'ADJ', 'Ich')]],
#  ['Lottens', [(9384, 'VERB', 'Lottens')]],
#  ['', [(9399, 'DET', 'ich')]],
#  ['Frau',
#   [(9776, 'PUNCT', 'Frau'),
#    (12459, 'SCONJ', 'Frau'),
#    (12511, 'ADV', 'Frau'),
#    (12525, 'AUX', 'Frau'),
#    (12560, 'DET', 'Ich'),
#    (12577, 'ADV', 'Ich'),
#    (12598, 'NOUN', 'ich'),
#    (12667, 'AUX', 'ich'),
#    (12678, 'DET', 'ich'),
#    (12700, 'PART', 'Frau'),
#    (12706, 'DET', 'Ich'),
#    (12756, 'SCONJ', 'Frau')]],
#  ['Frau',
#   [(10011, 'ADP', 'Frau'),
#    (10093, 'ADJ', 'Frau'),
#    (10142, 'AUX', 'Frau'),
#    (10982, 'ADP', 'Frau')]],
#  ['Frau',
#   [(10093, 'ADJ', 'Frau'), (10142, 'AUX', 'Frau'), (10152, 'NOUN', 'ich')]],
#  ['', [(10152, 'NOUN', 'ich')]],
#  ['Schmidt',
#   [(10184, 'PART', 'Schmidt'),
#    (10242, 'NOUN', 'Schmidt'),
#    (10293, 'ADP', 'Schmidt')]],
#  ['Friederike',
#   [(10369, 'SCONJ', 'Friederike'), (10789, 'ADP', 'Friederike')]],
#  ['', [(10645, 'PART', 'ich')]],
#  ['Lottens', [(11508, 'ADJ', 'Lottens')]],
#  ['Mariannen', [(11609, 'SCONJ', 'Mariannen')]],
#  ['Marianne', [(11609, 'SCONJ', 'Mariannen'), (11758, 'PUNCT', 'Marianne')]],
#  ['Lottchen', [(11777, 'PUNCT', 'Lottchen')]],
#  ['Lottens', [(12172, 'PUNCT', 'Lottens'), (12253, 'PUNCT', 'Lottens')]],
#  ['', [(12176, 'ADJ', 'ich')]],
#  ['Lottens', [(12317, 'PUNCT', 'Lottens')]],
#  ['', [(12911, 'PRON', 'ich')]],
#  ['', [(13562, 'PUNCT', 'Ich')]],
#  ['', [(13920, 'PUNCT', 'ich')]],
#  ['Großmutter', [(14143, 'PRON', 'Großmutter')]],
#  ['', [(14263, 'PROPN', 'ich')]],
#  ['', [(14767, 'ADV', 'ich')]],
#  ['',
#   [(15666, 'PUNCT', 'Ich'),
#    (15700, 'ADV', 'ich'),
#    (15705, 'PRON', 'ich'),
#    (15735, 'AUX', 'Ich')]],
#  ['', [(16344, 'PUNCT', 'Ich')]]]
